# %% [markdown]
# In this project, I am interested in extracting in the data relevant to my internship search such as title, location, company, and the link to apply.
#
# I used Beautiful Soup, a libary of Python to scrap web easily without strong knowledge in HTML

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = 'https://www.indeed.com/jobs?q=data+science+intern&l=San+Jose%2C+CA#'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser')

# %%
results = soup.find(id='resultsCol')

print(results.prettify())
# Out:
# <td id="resultsCol">
#  <div id="resultsColTopSpace">
#  </div>
#  <div class="messageContainer">
#   <script type="text/javascript">
#    function setRefineByCookie(refineByTypes) {
#         var expires = new Date();
#         expires.setTime(expires.getTime() + (10 * 1000));
#         for (var i = 0; i < refineByTypes.length; i++) {
#           setCookie(refineByTypes[i], "1", expires);
#         }
#       }
#   </script>
#  </div>
#  <style type="text/css">
#   #increased_radius_result {
#         font-size: 16px;
#         font-style: italic;
#     }
#     #original_radius_result{
#         font-size: 13px;
#         font-style: italic;
#         color: #666666;
#     }
#  </style>
#  <div class="resultsTop">
#   <div data-tn-section="resumePromo" id="resumePromo">
# ...

# %% [markdown]
# Find the job listings

# %%
job_elems = results.find_all('div',class_="jobsearch-SerpJobCard unifiedRow row result")

# %%
for job_elem in job_elems:
  print(job_elem, "\n"*2)
# Out:
# <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="4677e712f6cc6301" data-tn-component="organicJob" id="p_4677e712f6cc6301">
# <div class="title">
# <a class="jobtitle turnstileLink " data-tn-element="jobTitle" href="/rc/clk?jk=4677e712f6cc6301&amp;fccid=22efec3ff19e9e26&amp;vjs=3" id="jl_4677e712f6cc6301" onclick="setRefineByCookie([]); return rclk(this,jobmap[0],true,0);" onmousedown="return rclk(this,jobmap[0],0);" rel="noopener nofollow" target="_blank" title="Data Science Internship">
# <b>Data</b> <b>Science</b> Internship</a>
# </div>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Vectra" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=4677e712f6cc6301&amp;jcid=22efec3ff19e9e26')" rel="noopener" target="_blank">
# Vectra</a></span>
# <span class="ratingsDisplay">
# ...

# %% [markdown]
# Extract the non-relevant data to make the results easier to see

# %%
for job_elem in job_elems:

  title = job_elem.find('div', class_ = 'title')
  company = job_elem.find('span', class_='company')
  location = job_elem.find('span', class_ = "location accessible-contrast-color-location" )
  link = job_elem.find('a')['href']
  summary = job_elem.find('div', class_ = 'summary')
  print(title.text.strip())
  print(company.text.strip())
  print(location.text.strip())
  print()
  print("Apply here:", link)
  print()
# Out:
# Data Science Intern
# PayPal
# San Jose, CA 95131 (North Valley area)
#
# Apply here: /rc/clk?jk=f10b24d905e2d69d&fccid=978d9fd9799d55a8&vjs=3
#
# Data Science Internship
# Vectra
# San Jose, CA
#
# Apply here: /rc/clk?jk=4677e712f6cc6301&fccid=22efec3ff19e9e26&vjs=3
#
# Data Science Internship (Summer 2020)
# Poshmark
# Redwood City, CA
#
# Apply here: /rc/clk?jk=6e81a1bfd22f52dc&fccid=0f4f2d112db7d324&vjs=3
#
# ML/Data Science Intern (Summer 2020)
# Splunk
# San Jose, CA
#
# Apply here: /rc/clk?jk=936cd6393d5ca19d&fccid=aef928e89977f7f0&vjs=3
#
# Data Science Intern
# Bosch Group
# Sunnyvale, CA 94085
#
# Apply here: /rc/clk?jk=fc072cf68d7574af&fccid=a2faf1301ac6ad4b&vjs=3
#
# Data Scientist (Intern) - United States
# Cisco Careers
# San Jose, CA
#
# Apply here: /rc/clk?jk=93852554b89e8d9c&fccid=dfc44f3b8c44a6db&vjs=3
#
# Data Science Intern
# Wealthfront
# Palo Alto, CA 94301 (Professorville area)
#
# Apply here: /rc/clk?jk=3733a03f5b6a48ea&fccid=90344e51e9e06acc&vjs=3
#
# ...
